# %%
#Dates and times.
import datetime as dt

# Data frames.
import pandas as pd

#yFinance for stock data.
import yfinance as yf

# %% [markdown]
# ###Testing the datetime library
#
# https://docs.python.org/3/library/datetime.html?utm_source=chatgpt.com

# %%
data = dt.date (2024, 10, 24)
print(data)
# Out:
# 2024-10-24

# %%
print (data.ctime())
# Out:
# Thu Oct 24 00:00:00 2024

# %%
day = data.day
month = data.month
year = data.year
print (day, month, year)
# Out:
# 24 10 2024

# %%
nova_data = data.replace(month =7)
print (nova_data)
print (data)
# Out:
# 2024-07-24
# 2024-10-24

# %%
import yfinance as yf

dat = yf.Ticker("MSFT")
dat

dat.info
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software - Infrastructure',
#  'industryKey': 'software-infrastructure',
#  'industryDisp': 'Software - Infrastructure',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
dat.calendar
# Out:
# {'Dividend Date': datetime.date(2025, 12, 11),
#  'Ex-Dividend Date': datetime.date(2025, 11, 20),
#  'Earnings Date': [datetime.date(2026, 1, 28)],
#  'Earnings High': 4.29,
#  'Earnings Low': 3.59,
#  'Earnings Average': 3.92677,
#  'Revenue High': 81661025500,
#  'Revenue Low': 78581000000,
#  'Revenue Average': 80220963190}

# %%
dat.analyst_price_targets
# Out:
# {'current': 517.81,
#  'high': 730.0,
#  'low': 483.0,
#  'mean': 626.265,
#  'median': 637.65}

# %% [markdown]
# #Single Ticket

# %%
dat.history(period="1mo")
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-10-01 00:00:00-04:00  514.799988  520.510010  511.690002  519.710022
# 2025-10-02 00:00:00-04:00  517.640015  521.599976  510.679993  515.739990
# 2025-10-03 00:00:00-04:00  517.099976  520.489990  515.000000  517.349976
# 2025-10-06 00:00:00-04:00  518.609985  531.030029  518.200012  528.570007
# 2025-10-07 00:00:00-04:00  528.289978  529.799988  521.440002  523.979980
# 2025-10-08 00:00:00-04:00  523.280029  526.950012  523.090027  524.849976
# 2025-10-09 00:00:00-04:00  522.340027  524.330017  517.400024  522.400024
# 2025-10-10 00:00:00-04:00  519.640015  523.580017  509.630005  510.959991
# 2025-10-13 00:00:00-04:00  516.409973  516.409973  511.679993  514.049988
# 2025-10-14 00:00:00-04:00  510.230011  515.280029  506.000000  513.570007
# 2025-10-15 00:00:00-04:00  514.960022  517.190002  510.000000  513.429993
# 2025-10-16 00:00:00-04:00  512.580017  516.849976  508.130005  511.609985
# ...

# %% [markdown]
# #Multiple Tickets:
# #Create a Tickers obejt to work with multiple tickers at once.
#
# https://github.com/ranaroussi/yfinance#tickers

# %%
tickers = yf.Tickers("msft aapl goog")

tickers
# Out:
# yfinance.Tickers object <MSFT,AAPL,GOOG>

# %%
yf.download(["MSFT", "AAPL", "GOOG"],period='1mo')
# Out:
# C:\Users\Julia Cruz\AppData\Local\Temp\ipykernel_17472\452508005.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   yf.download(["MSFT", "AAPL", "GOOG"],period='1mo')
# [*********************100%***********************]  3 of 3 completed
# Price            Close                                High              \
# Ticker            AAPL        GOOG        MSFT        AAPL        GOOG
# Date
# 2025-10-01  255.449997  245.539993  519.710022  258.790009  247.149994
# 2025-10-02  257.130005  246.429993  515.739990  258.179993  247.634995
# 2025-10-03  258.019989  246.449997  517.349976  259.239990  247.117996
# 2025-10-06  256.690002  251.509995  528.570007  259.070007  252.199997
# 2025-10-07  256.480011  247.130005  523.979980  257.399994  251.550003
# 2025-10-08  258.059998  245.460007  524.849976  258.519989  247.259995
# 2025-10-09  254.039993  242.210007  522.400024  258.000000  245.554993
# ...

# %%
df = yf.download("MSFT AAPL GOOG", period="1mo")
# Out:
# C:\Users\Julia Cruz\AppData\Local\Temp\ipykernel_17472\3326052708.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download("MSFT AAPL GOOG", period="1mo")
# [*********************100%***********************]  3 of 3 completed

# %%
df.columns
# Out:
# MultiIndex([( 'Close', 'AAPL'),
#             ( 'Close', 'GOOG'),
#             ( 'Close', 'MSFT'),
#             (  'High', 'AAPL'),
#             (  'High', 'GOOG'),
#             (  'High', 'MSFT'),
#             (   'Low', 'AAPL'),
#             (   'Low', 'GOOG'),
#             (   'Low', 'MSFT'),
#             (  'Open', 'AAPL'),
#             (  'Open', 'GOOG'),
#             (  'Open', 'MSFT'),
#             ('Volume', 'AAPL'),
#             ('Volume', 'GOOG'),
#             ('Volume', 'MSFT')],
#            names=['Price', 'Ticker'])

# %%
df.index
# Out:
# DatetimeIndex(['2025-10-01', '2025-10-02', '2025-10-03', '2025-10-06',
#                '2025-10-07', '2025-10-08', '2025-10-09', '2025-10-10',
#                '2025-10-13', '2025-10-14', '2025-10-15', '2025-10-16',
#                '2025-10-17', '2025-10-20', '2025-10-21', '2025-10-22',
#                '2025-10-23', '2025-10-24', '2025-10-27', '2025-10-28',
#                '2025-10-29', '2025-10-30', '2025-10-31'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
df= yf.download("MSFT AAPL GOOG", period='5d',interval='1h')
df
# Out:
# C:\Users\Julia Cruz\AppData\Local\Temp\ipykernel_17472\1000381617.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df= yf.download("MSFT AAPL GOOG", period='5d',interval='1h')
# [*********************100%***********************]  3 of 3 completed
# Price                           Close                                High  \
# Ticker                           AAPL        GOOG        MSFT        AAPL
# Datetime
# 2025-10-27 13:30:00+00:00  265.730011  265.640015  533.224976  267.049988
# 2025-10-27 14:30:00+00:00  265.709991  267.070007  532.665100  266.420013
# 2025-10-27 15:30:00+00:00  265.929993  267.587402  531.719971  266.089996
# 2025-10-27 16:30:00+00:00  265.619995  268.320007  530.794983  266.125000
# 2025-10-27 17:30:00+00:00  265.595001  269.459991  532.520020  266.015015
# 2025-10-27 18:30:00+00:00  267.274994  268.839996  532.830017  267.399994
# 2025-10-27 19:30:00+00:00  268.739990  269.839996  531.409973  269.079987
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.index
# Out:
# DatetimeIndex(['2025-10-27 13:30:00+00:00', '2025-10-27 14:30:00+00:00',
#                '2025-10-27 15:30:00+00:00', '2025-10-27 16:30:00+00:00',
#                '2025-10-27 17:30:00+00:00', '2025-10-27 18:30:00+00:00',
#                '2025-10-27 19:30:00+00:00', '2025-10-28 13:30:00+00:00',
#                '2025-10-28 14:30:00+00:00', '2025-10-28 15:30:00+00:00',
#                '2025-10-28 16:30:00+00:00', '2025-10-28 17:30:00+00:00',
#                '2025-10-28 18:30:00+00:00', '2025-10-28 19:30:00+00:00',
#                '2025-10-29 13:30:00+00:00', '2025-10-29 14:30:00+00:00',
#                '2025-10-29 15:30:00+00:00', '2025-10-29 16:30:00+00:00',
#                '2025-10-29 17:30:00+00:00', '2025-10-29 18:30:00+00:00',
#                '2025-10-29 19:30:00+00:00', '2025-10-30 13:30:00+00:00',
#                '2025-10-30 14:30:00+00:00', '2025-10-30 15:30:00+00:00',
#                '2025-10-30 16:30:00+00:00', '2025-10-30 17:30:00+00:00',
# ...

# %%
print(df.to_csv())
# Out:
# Price,Close,Close,Close,High,High,High,Low,Low,Low,Open,Open,Open,Volume,Volume,Volume
# Ticker,AAPL,GOOG,MSFT,AAPL,GOOG,MSFT,AAPL,GOOG,MSFT,AAPL,GOOG,MSFT,AAPL,GOOG,MSFT
# Datetime,,,,,,,,,,,,,,,
# 2025-10-27 13:30:00+00:00,265.7300109863281,265.6400146484375,533.2249755859375,267.04998779296875,267.3399963378906,533.7999267578125,264.65008544921875,264.94000244140625,529.010009765625,264.8800048828125,265.364990234375,531.7091064453125,9319511,5470537,4991642
# 2025-10-27 14:30:00+00:00,265.7099914550781,267.07000732421875,532.6651000976562,266.4200134277344,267.1700134277344,534.5800170898438,265.19500732421875,265.0400085449219,532.239990234375,265.739990234375,265.6400146484375,533.260009765625,4050852,2353304,2235243
# ...

# %% [markdown]
# # Save data as CSV.

# %%
df.to_csv('../8645-computer-infrastructure/data/stock_data.csv')

# %%
now = dt.datetime.now()

now
# Out:
# datetime.datetime(2025, 11, 3, 14, 24, 51, 242887)

# %%
now.strftime("%Y-%m-%d %H:%M:%S")
# Out:
# '2025-11-03 14:24:51'

# %%
'../8645-computer-infrastructure/data/stock_data.csv'+now.strftime("_%Y%m%d_%H%M%S")+'.csv'
# Out:
# '../8645-computer-infrastructure/data/stock_data.csv_20251103_142451.csv'

# %%
df.to_csv('../8645-computer-infrastructure/data/stock_data.csv'+  dt.datetime.now().strftime("_%Y%m%d_%H%M%S")+'.csv')
